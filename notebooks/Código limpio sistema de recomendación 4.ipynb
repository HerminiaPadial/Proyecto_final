# %% [markdown]
# ## Imports

# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Lectura input

# %%
path = '/Users/herminiapadialromera/ironhackb/Proyecto_final/notebooks/input_sist_recom_4.json'
pd.set_option('display.max_colwidth', None)
df_input_json = pd.read_json(path)

def check_educ_creci():
    if 'Educación & Crecimiento' in df_input_json['Temática']:
        pass
    else:
        df_input_json['Temática'][0].append('Educación & Crecimiento')
    return df_input_json

df_input_json = check_educ_creci()

columnas_explode = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
df_input_json_merge = df_input_json.explode(['Etapa']).explode(['Formato']).explode(['Objetivos']).explode(['Temática'])
df_input_json_merge
# Out:
#    Provincia Name_center Religious       Etapa                 Temática
# 0  Barcelona   Greenwich        No    Primaria     Familia & Tecnología  \
# 0  Barcelona   Greenwich        No    Primaria           Arte & Cultura
# 0  Barcelona   Greenwich        No    Primaria  Educación & Crecimiento
# 0  Barcelona   Greenwich        No    Primaria     Familia & Tecnología
# 0  Barcelona   Greenwich        No    Primaria           Arte & Cultura
# 0  Barcelona   Greenwich        No    Primaria  Educación & Crecimiento
# 0  Barcelona   Greenwich        No  Secundaria     Familia & Tecnología
# 0  Barcelona   Greenwich        No  Secundaria           Arte & Cultura
# 0  Barcelona   Greenwich        No  Secundaria  Educación & Crecimiento
# 0  Barcelona   Greenwich        No  Secundaria     Familia & Tecnología
# 0  Barcelona   Greenwich        No  Secundaria           Arte & Cultura
# 0  Barcelona   Greenwich        No  Secundaria  Educación & Crecimiento
#
#                                                             Objetivos
# 0  Solucionar problemas de comunicacion y actitud de niños y familias  \
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller
# 0  Presencial    Entre 100 y 300
# 0  Presencial    Entre 100 y 300
# 0  Presencial    Entre 100 y 300
# 0      Online    Entre 100 y 300
# 0      Online    Entre 100 y 300
# 0      Online    Entre 100 y 300
# 0  Presencial    Entre 100 y 300
# 0  Presencial    Entre 100 y 300
# 0  Presencial    Entre 100 y 300
# 0      Online    Entre 100 y 300
# 0      Online    Entre 100 y 300
# 0      Online    Entre 100 y 300

# %% [markdown]
# ## Lectura del dataset de cursos

# %%
data_course_df = pd.read_csv('/Users/herminiapadialromera/ironhackb/Proyecto_final/data/Datos_ampliados.csv', sep=";", encoding='utf8')
data_course_df = pd.DataFrame(data_course_df)
data_course_df['Tipo de contenido'].fillna('No innovador', inplace= True)
columnas_explode_curso = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
data_course_df = data_course_df.explode(['Etapa']).explode(['Formato']).explode(['Temática'])
data_course_df
# Out:
#                                                       Título         Etapa
# 0              ¡Ponte al día con la Inteligencia Artificial!  Bachillerato  \
# 1              ¡Ponte al día con la Inteligencia Artificial!      Infantil
# 2              ¡Ponte al día con la Inteligencia Artificial!      Primaria
# 3              ¡Ponte al día con la Inteligencia Artificial!    Secundaria
# 4     ¿Qué harías si tu hijo fuera adicto a los videojuegos?  Bachillerato
# ..                                                       ...           ...
# 263  Violencia: Identificación y prevención con las familias      Infantil
# 264  Violencia: Identificación y prevención con las familias      Primaria
# 265  Violencia: Identificación y prevención con las familias      Primaria
# 266  Violencia: Identificación y prevención con las familias    Secundaria
# 267  Violencia: Identificación y prevención con las familias    Secundaria
#
#         Formato  Nº Sesiones                 Temática  Precio por taller
# 0        Online            5     Familia & Tecnología                130  \
# 1        Online            5     Familia & Tecnología                130
# 2        Online            5     Familia & Tecnología                130
# 3        Online            5     Familia & Tecnología                130
# 4    Presencial            3     Familia & Tecnología                100
# ..          ...          ...                      ...                ...
# 263      Online            3  Educación & Crecimiento                250
# 264  Presencial            3  Educación & Crecimiento                250
# 265      Online            3  Educación & Crecimiento                250
# 266  Presencial            3  Educación & Crecimiento                250
# 267      Online            3  Educación & Crecimiento                250
#
#      Provincia Tipo de contenido  Valoración
# 0       Madrid         Innovador           3
# 1       Madrid         Innovador           4
# 2       Madrid         Innovador           2
# 3       Madrid         Innovador           4
# 4    Barcelona         Innovador           2
# ..         ...               ...         ...
# 263   Valencia      No innovador           4
# 264   Valencia      No innovador           1
# 265   Valencia      No innovador           3
# 266   Valencia      No innovador           4
# 267   Valencia      No innovador           1
#
# [268 rows x 9 columns]

# %% [markdown]
# ## Merge de los dos dataframe

# %%
df_merge = pd.merge(df_input_json_merge, data_course_df, on=['Provincia', 'Etapa', 'Formato', 'Temática'])
df_merge = df_merge.iloc[:,1:]
df_merge
# Out:
#    Name_center Religious       Etapa                 Temática
# 0    Greenwich        No    Primaria     Familia & Tecnología  \
# 1    Greenwich        No    Primaria     Familia & Tecnología
# 2    Greenwich        No    Primaria     Familia & Tecnología
# 3    Greenwich        No    Primaria  Educación & Crecimiento
# 4    Greenwich        No    Primaria     Familia & Tecnología
# 5    Greenwich        No    Primaria     Familia & Tecnología
# 6    Greenwich        No    Primaria     Familia & Tecnología
# 7    Greenwich        No    Primaria  Educación & Crecimiento
# 8    Greenwich        No  Secundaria     Familia & Tecnología
# 9    Greenwich        No  Secundaria     Familia & Tecnología
# 10   Greenwich        No  Secundaria     Familia & Tecnología
# 11   Greenwich        No  Secundaria     Familia & Tecnología
# 12   Greenwich        No  Secundaria           Arte & Cultura
# 13   Greenwich        No  Secundaria  Educación & Crecimiento
# 14   Greenwich        No  Secundaria     Familia & Tecnología
# 15   Greenwich        No  Secundaria     Familia & Tecnología
# 16   Greenwich        No  Secundaria     Familia & Tecnología
# 17   Greenwich        No  Secundaria           Arte & Cultura
# 18   Greenwich        No  Secundaria  Educación & Crecimiento
#
#                                                              Objetivos
# 0   Solucionar problemas de comunicacion y actitud de niños y familias  \
# 1   Solucionar problemas de comunicacion y actitud de niños y familias
# 2   Solucionar problemas de comunicacion y actitud de niños y familias
# 3   Solucionar problemas de comunicacion y actitud de niños y familias
# 4   Solucionar problemas de comunicacion y actitud de niños y familias
# 5   Solucionar problemas de comunicacion y actitud de niños y familias
# 6   Solucionar problemas de comunicacion y actitud de niños y familias
# 7   Solucionar problemas de comunicacion y actitud de niños y familias
# 8   Solucionar problemas de comunicacion y actitud de niños y familias
# 9   Solucionar problemas de comunicacion y actitud de niños y familias
# 10  Solucionar problemas de comunicacion y actitud de niños y familias
# 11  Solucionar problemas de comunicacion y actitud de niños y familias
# 12  Solucionar problemas de comunicacion y actitud de niños y familias
# 13  Solucionar problemas de comunicacion y actitud de niños y familias
# 14  Solucionar problemas de comunicacion y actitud de niños y familias
# 15  Solucionar problemas de comunicacion y actitud de niños y familias
# 16  Solucionar problemas de comunicacion y actitud de niños y familias
# 17  Solucionar problemas de comunicacion y actitud de niños y familias
# 18  Solucionar problemas de comunicacion y actitud de niños y familias
#
#        Formato Precios por taller
# 0   Presencial    Entre 100 y 300  \
# 1   Presencial    Entre 100 y 300
# 2   Presencial    Entre 100 y 300
# 3   Presencial    Entre 100 y 300
# 4       Online    Entre 100 y 300
# 5       Online    Entre 100 y 300
# 6       Online    Entre 100 y 300
# 7       Online    Entre 100 y 300
# 8   Presencial    Entre 100 y 300
# 9   Presencial    Entre 100 y 300
# 10  Presencial    Entre 100 y 300
# 11  Presencial    Entre 100 y 300
# 12  Presencial    Entre 100 y 300
# 13  Presencial    Entre 100 y 300
# 14      Online    Entre 100 y 300
# 15      Online    Entre 100 y 300
# 16      Online    Entre 100 y 300
# 17      Online    Entre 100 y 300
# 18      Online    Entre 100 y 300
#
#                                                     Título  Nº Sesiones
# 0   ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3  \
# 1                              Aprende a Diseñar con Canva            5
# 2         Creación de Animaciones Interactivas con Scratch            3
# 3                   Desarrollo de habilidades lingüísticas            5
# 4   ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 5                      Dibujo y Pintura Digital para Niños            5
# 6          Explorando el Diseño de Videojuegos con Scratch            3
# 7                                    Familias Inteligentes            2
# 8   ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 9                        Aprendiendo a Programar en Python            3
# 10                 Descubriendo el universo de la biología            5
# 11                  Descubriendo el universo de la química            5
# 12           Fomentando la Creatividad a través del Teatro            4
# 13                  Desarrollando habilidades de liderazgo            5
# 14  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 15               Descubriendo el universo de la astronomía            5
# 16       Introducción a la Programación Web con HTML y CSS            3
# 17            Descubre el Arte de la Improvisación Teatral            4
# 18                                   Familias Inteligentes            2
#
#     Precio por taller Tipo de contenido  Valoración
# 0                 100         Innovador           1
# 1                  80      No innovador           4
# 2                 100         Innovador           3
# 3                 200      No innovador           4
# 4                 100         Innovador           2
# 5                  80      No innovador           5
# 6                 100         Innovador           1
# 7                 200         Innovador           2
# 8                 100         Innovador           3
# 9                 100         Innovador           5
# 10                180      No innovador           5
# 11                180      No innovador           4
# 12                400         Innovador           1
# 13                180      No innovador           2
# 14                100         Innovador           5
# 15                180      No innovador           2
# 16                100         Innovador           2
# 17                150         Innovador           3
# 18                200         Innovador           1

# %% [markdown]
# ## FILTROS

# %% [markdown]
#    ## Filtro temática ed_crecimiento

# %%
def filtro_edcrecim_tematica (df, sesiones):
    tematica_unique_list = df_merge['Temática'].unique()

    filtro_crecim_tematica_df = pd.DataFrame()
    for tematica in tematica_unique_list:
        df_crecim_tematica = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Temática'] == tematica)]
        filtro_crecim_tematica_df = pd.concat([filtro_crecim_tematica_df, df_crecim_tematica.head(1)])

    recomendaciones_filtro_crecim_tematica_df = filtro_crecim_tematica_df.drop_duplicates().reset_index(drop=True)

    return recomendaciones_filtro_crecim_tematica_df

# %%
recomendacion_4 = filtro_edcrecim_tematica(df_merge, 5)
recomendacion_4
# Out:
#   Name_center Religious       Etapa                 Temática
# 0   Greenwich        No    Primaria     Familia & Tecnología  \
# 1   Greenwich        No    Primaria  Educación & Crecimiento
# 2   Greenwich        No  Secundaria           Arte & Cultura
#
#                                                             Objetivos
# 0  Solucionar problemas de comunicacion y actitud de niños y familias  \
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
# 2  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller
# 0  Presencial    Entre 100 y 300  \
# 1  Presencial    Entre 100 y 300
# 2  Presencial    Entre 100 y 300
#
#                                                    Título  Nº Sesiones
# 0  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3  \
# 1                  Desarrollo de habilidades lingüísticas            5
# 2           Fomentando la Creatividad a través del Teatro            4
#
#    Precio por taller Tipo de contenido  Valoración
# 0                100         Innovador           1
# 1                200      No innovador           4
# 2                400         Innovador           1
