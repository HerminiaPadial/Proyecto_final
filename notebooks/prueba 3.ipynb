# %%
import json
import pandas as pd
import numpy as np

# %%
def lectura_input(): 
    path = '/Users/herminiapadialromera/ironhackb/Proyecto_final/notebooks/input_sist_recom_4.json'
    pd.set_option('display.max_colwidth', None)
    df_input_json = pd.read_json(path)
    columnas_explode = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
    df_input_json_merge = df_input_json.explode(['Etapa']).explode(['Formato']).explode(['Objetivos']).explode(['Temática'])
    return df_input_json_merge  #DF1

def lectura_cursos():
    data_course_df = pd.read_csv('/Users/herminiapadialromera/ironhackb/Proyecto_final/data/Datos_ampliados.csv', sep=";", encoding='utf8')
    data_course_df = pd.DataFrame(data_course_df)
    data_course_df['Tipo de contenido'].fillna('No innovador', inplace=True)
    columnas_explode_curso = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
    data_course_df = data_course_df.explode(['Etapa']).explode(['Formato']).explode(['Temática'])
    return data_course_df #DF2

def merge(df_input_json_merge, data_course_df):
    df_merge = pd.merge(df_input_json_merge, data_course_df, on=['Provincia', 'Etapa', 'Formato', 'Temática'])
    df_merge = df_merge.iloc[:, 1:]
    return df_merge  #DF FINAL

# %%
def lectura_datos():
   
    df_input_json_merge = lectura_input()  # Llamada a la función lectura_input
    data_course_df = lectura_cursos()  # Llamada a la función lectura_cursos
    prueba_lectura = merge(df_input_json_merge, data_course_df)  # Llamada a la función merge

    return prueba_lectura

# %%
lectura = lectura_datos()
lectura
##NUEVO DATAFRAME GENERADO CON TODO EL CONTENIDO DE INPUT Y CURSOS MERGEADO
# Out:
#    Name_center Religious       Etapa              Temática  \
# 0    Greenwich        No    Primaria  Familia & Tecnología
# 1    Greenwich        No    Primaria  Familia & Tecnología
# 2    Greenwich        No    Primaria  Familia & Tecnología
# 3    Greenwich        No    Primaria  Familia & Tecnología
# 4    Greenwich        No    Primaria  Familia & Tecnología
# 5    Greenwich        No    Primaria  Familia & Tecnología
# 6    Greenwich        No  Secundaria  Familia & Tecnología
# 7    Greenwich        No  Secundaria  Familia & Tecnología
# 8    Greenwich        No  Secundaria  Familia & Tecnología
# 9    Greenwich        No  Secundaria  Familia & Tecnología
# 10   Greenwich        No  Secundaria        Arte & Cultura
# 11   Greenwich        No  Secundaria  Familia & Tecnología
# 12   Greenwich        No  Secundaria  Familia & Tecnología
# 13   Greenwich        No  Secundaria  Familia & Tecnología
# 14   Greenwich        No  Secundaria        Arte & Cultura
#
#                                                              Objetivos  \
# 0   Solucionar problemas de comunicacion y actitud de niños y familias
# 1   Solucionar problemas de comunicacion y actitud de niños y familias
# 2   Solucionar problemas de comunicacion y actitud de niños y familias
# 3   Solucionar problemas de comunicacion y actitud de niños y familias
# 4   Solucionar problemas de comunicacion y actitud de niños y familias
# 5   Solucionar problemas de comunicacion y actitud de niños y familias
# 6   Solucionar problemas de comunicacion y actitud de niños y familias
# 7   Solucionar problemas de comunicacion y actitud de niños y familias
# 8   Solucionar problemas de comunicacion y actitud de niños y familias
# 9   Solucionar problemas de comunicacion y actitud de niños y familias
# 10  Solucionar problemas de comunicacion y actitud de niños y familias
# 11  Solucionar problemas de comunicacion y actitud de niños y familias
# 12  Solucionar problemas de comunicacion y actitud de niños y familias
# 13  Solucionar problemas de comunicacion y actitud de niños y familias
# 14  Solucionar problemas de comunicacion y actitud de niños y familias
#
#        Formato Precios por taller  \
# 0   Presencial    Entre 100 y 300
# 1   Presencial    Entre 100 y 300
# 2   Presencial    Entre 100 y 300
# 3       Online    Entre 100 y 300
# 4       Online    Entre 100 y 300
# 5       Online    Entre 100 y 300
# 6   Presencial    Entre 100 y 300
# 7   Presencial    Entre 100 y 300
# 8   Presencial    Entre 100 y 300
# 9   Presencial    Entre 100 y 300
# 10  Presencial    Entre 100 y 300
# 11      Online    Entre 100 y 300
# 12      Online    Entre 100 y 300
# 13      Online    Entre 100 y 300
# 14      Online    Entre 100 y 300
#
#                                                     Título  Nº Sesiones  \
# 0   ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 1                              Aprende a Diseñar con Canva            5
# 2         Creación de Animaciones Interactivas con Scratch            3
# 3   ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 4                      Dibujo y Pintura Digital para Niños            5
# 5          Explorando el Diseño de Videojuegos con Scratch            3
# 6   ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 7                        Aprendiendo a Programar en Python            3
# 8                  Descubriendo el universo de la biología            5
# 9                   Descubriendo el universo de la química            5
# 10           Fomentando la Creatividad a través del Teatro            4
# 11  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 12               Descubriendo el universo de la astronomía            5
# 13       Introducción a la Programación Web con HTML y CSS            3
# 14            Descubre el Arte de la Improvisación Teatral            4
#
#     Precio por taller Tipo de contenido  Valoración
# 0                 100         Innovador           1
# 1                  80      No innovador           4
# 2                 100         Innovador           3
# 3                 100         Innovador           2
# 4                  80      No innovador           5
# 5                 100         Innovador           1
# 6                 100         Innovador           3
# 7                 100         Innovador           5
# 8                 180      No innovador           5
# 9                 180      No innovador           4
# 10                400         Innovador           1
# 11                100         Innovador           5
# 12                180      No innovador           2
# 13                100         Innovador           2
# 14                150         Innovador           3

# %% [markdown]
# ## Filtro SR1

# %%
def filtro_tematica_etapa_formato(df_merge, sesiones):
    tematica_unique_list = df_merge['Temática'].unique()
    formato_unique_list = df_merge['Formato'].unique()
    etapa_unique_list = df_merge['Etapa'].unique()

    filtro_tematica_df = pd.DataFrame()
    for tematica in tematica_unique_list:
        df_tematica_temp = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Temática'] == tematica)].iloc[:1,:]
        filtro_tematica_df = pd.concat([filtro_tematica_df, df_tematica_temp])
        #print("filtro_tematica_df ---> ", tematica)
        #display(filtro_tematica_df)

    filtro_formato_df = pd.DataFrame()
    for formato in formato_unique_list:
        df_formato = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Formato'] == formato)].iloc[:1,:]
        filtro_formato_df = pd.concat([filtro_formato_df, df_formato])
        #print("filtro_formato_df ---> ", formato)
        #display(filtro_formato_df)

    filtro_etapa_df = pd.DataFrame()
    for etapa in etapa_unique_list:
        df_etapa = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Etapa'] == etapa)].iloc[:1,:]
        filtro_etapa_df = pd.concat([filtro_etapa_df, df_etapa])
        #print("filtro_etapa_df ---> ", etapa)
        #display(filtro_etapa_df)

    recomendaciones_df = pd.concat([filtro_tematica_df,filtro_formato_df,filtro_etapa_df]).drop_duplicates().reset_index(drop=True)

    return recomendaciones_df


def filtro_precio(tematica_formato_etapa_df):
    if (tematica_formato_etapa_df['Precios por taller'] == 'Menos de 100').any():
        precio_df = tematica_formato_etapa_df[(tematica_formato_etapa_df['Precio por taller'] < 100)]
        print("menos de 100 ---> existe")

    elif (tematica_formato_etapa_df['Precios por taller'] == 'Entre 100 y 300').any():
        precio_df = tematica_formato_etapa_df[(tematica_formato_etapa_df['Precio por taller'] >= 100) & (tematica_formato_etapa_df['Precio por taller'] <= 300)]
        print("entre 100 y 300 ---> existe")

    else:
        precio_df = tematica_formato_etapa_df[(tematica_formato_etapa_df['Precio por taller'] > 300)]
        print("más de 300 ---> existe")
    precio_df= precio_df.reset_index(drop=True)
    
    return precio_df

# %% [markdown]
# ## Filtro SR2

# %%
def filtro_valoracion_tematica(df_merge, sesiones):
    tematica_unique_list = df_merge['Temática'].unique()

    filtro_tematica_df = pd.DataFrame()
    for tematica in tematica_unique_list:
        df_tematica= df_merge[(df_merge['Nº Sesiones'] <= int(sesiones)) & (df_merge['Temática'] == tematica)].sort_values(by='Valoración', ascending=False).reset_index(drop=True)
        filtro_tematica_df = pd.concat([filtro_tematica_df, df_tematica.head(2)])
        #print("filtro_tematica_df ---> ", tematica)
    
    recomendaciones_valoracion_tema_df = filtro_tematica_df.drop_duplicates()

    
    return recomendaciones_valoracion_tema_df

# %%
#Prueba función filtro_valoracion_tematica
filtro_valoracion_tematica_df = filtro_valoracion_tematica(lectura, 5)
filtro_valoracion_tematica_df
# Out:
#   Name_center Religious       Etapa              Temática  \
# 0   Greenwich        No    Primaria  Familia & Tecnología
# 1   Greenwich        No  Secundaria  Familia & Tecnología
# 0   Greenwich        No  Secundaria        Arte & Cultura
# 1   Greenwich        No  Secundaria        Arte & Cultura
#
#                                                             Objetivos  \
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller  \
# 0      Online    Entre 100 y 300
# 1  Presencial    Entre 100 y 300
# 0      Online    Entre 100 y 300
# 1  Presencial    Entre 100 y 300
#
#                                           Título  Nº Sesiones  \
# 0            Dibujo y Pintura Digital para Niños            5
# 1              Aprendiendo a Programar en Python            3
# 0   Descubre el Arte de la Improvisación Teatral            4
# 1  Fomentando la Creatividad a través del Teatro            4
#
#    Precio por taller Tipo de contenido  Valoración
# 0                 80      No innovador           5
# 1                100         Innovador           5
# 0                150         Innovador           3
# 1                400         Innovador           1

# %% [markdown]
# ## Filtro SR3

# %%
def filtro_innovación_tematica (df_merge, sesiones):
    tematica_unique_list = df_merge['Temática'].unique()

    filtro_inno_tematica_df = pd.DataFrame()
    for tematica in tematica_unique_list:
        df_inno_tematica = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Tipo de contenido'] == 'Innovador') & (df_merge['Temática'] == tematica)]
        filtro_inno_tematica_df = pd.concat([filtro_inno_tematica_df, df_inno_tematica.head(2)])
        #print("filtro_inno_tematica_df ---> ", tematica)

    recomendaciones_innovacion_tema_df = filtro_inno_tematica_df.drop_duplicates().reset_index(drop=True)

    return recomendaciones_innovacion_tema_df

# %%
filtro_innovación_tematica_df = filtro_innovación_tematica(lectura, 5)
filtro_innovación_tematica_df
# Out:
#   Name_center Religious       Etapa              Temática  \
# 0   Greenwich        No    Primaria  Familia & Tecnología
# 1   Greenwich        No    Primaria  Familia & Tecnología
# 2   Greenwich        No  Secundaria        Arte & Cultura
# 3   Greenwich        No  Secundaria        Arte & Cultura
#
#                                                             Objetivos  \
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
# 2  Solucionar problemas de comunicacion y actitud de niños y familias
# 3  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller  \
# 0  Presencial    Entre 100 y 300
# 1  Presencial    Entre 100 y 300
# 2  Presencial    Entre 100 y 300
# 3      Online    Entre 100 y 300
#
#                                                    Título  Nº Sesiones  \
# 0  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 1        Creación de Animaciones Interactivas con Scratch            3
# 2           Fomentando la Creatividad a través del Teatro            4
# 3            Descubre el Arte de la Improvisación Teatral            4
#
#    Precio por taller Tipo de contenido  Valoración
# 0                100         Innovador           1
# 1                100         Innovador           3
# 2                400         Innovador           1
# 3                150         Innovador           3

# %%
ob1= 'Ofrecer formación variada'
ob2= 'Aumentar la participación de las familias'
ob3= 'Sorprender con contenidos innovadores y formatos novedosos'

if lectura['Objetivos'].str.contains(ob3).any():
    print("Está")
else:
    print("NO Está!!!!!!!")
# Out:
# NO Está!!!!!!!

# %%
#display(filtro_tematica_etapa_formato(lectura, sesiones=3))

# %%
tematica_formato_etapa_df_test = filtro_tematica_etapa_formato(lectura, 5)
filtro_precio_df = filtro_precio(tematica_formato_etapa_df_test)
filtro_precio_df
# Out:
# entre 100 y 300 ---> existe
#   Name_center Religious       Etapa              Temática  \
# 0   Greenwich        No    Primaria  Familia & Tecnología
# 1   Greenwich        No    Primaria  Familia & Tecnología
# 2   Greenwich        No  Secundaria  Familia & Tecnología
#
#                                                             Objetivos  \
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
# 2  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller  \
# 0  Presencial    Entre 100 y 300
# 1      Online    Entre 100 y 300
# 2  Presencial    Entre 100 y 300
#
#                                                    Título  Nº Sesiones  \
# 0  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 1  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 2  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
#
#    Precio por taller Tipo de contenido  Valoración
# 0                100         Innovador           1
# 1                100         Innovador           2
# 2                100         Innovador           3

# %%
lectura['Objetivos'][0] == ob1
# Out:
# False

# %%
len(lectura['Objetivos'])
# Out:
# 15

# %% [markdown]
# ## Filtro SR4

# %%
def check_educ_creci():
    path = '/Users/herminiapadialromera/ironhackb/Proyecto_final/notebooks/input_sist_recom_4.json'
    pd.set_option('display.max_colwidth', None)
    df_input_json = pd.read_json(path)
    
    if df_input_json['Temática'].str.contains('Educación & Crecimiento').any():
        pass
    
    else:
        df_input_json['Temática'][0].append('Educación & Crecimiento')
        print("Se agregó 'Educación & Crecimiento' a df_input_json['Temática']")
        columnas_explode = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
        df_input_json_merge = df_input_json.explode(['Etapa']).explode(['Formato']).explode(['Objetivos']).explode(['Temática'])
        data_course_df = lectura_cursos()  # Llamada a la función lectura_cursos
        prueba_lectura = merge(df_input_json_merge, data_course_df)  # Llamada a la función merge
        
        return prueba_lectura
    
def filtro_edcrecim_tematica (df_merge, sesiones):
    tematica_unique_list = df_merge['Temática'].unique()

    filtro_crecim_tematica_df = pd.DataFrame()
    for tematica in tematica_unique_list:
        df_crecim_tematica = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Temática'] == tematica)]
        filtro_crecim_tematica_df = pd.concat([filtro_crecim_tematica_df, df_crecim_tematica.head(1)])

    recomendaciones_filtro_crecim_tematica_df = filtro_crecim_tematica_df.drop_duplicates().reset_index(drop=True)

    return recomendaciones_filtro_crecim_tematica_df

# %%
df_sr4 = check_educ_creci()
display(filtro_edcrecim_tematica(df_sr4, 5))
# Out:
# Se agregó 'Educación & Crecimiento' a df_input_json['Temática']
#   Name_center Religious       Etapa                 Temática  \
# 0   Greenwich        No    Primaria     Familia & Tecnología
# 1   Greenwich        No    Primaria  Educación & Crecimiento
# 2   Greenwich        No  Secundaria           Arte & Cultura
#
#                                                             Objetivos  \
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
# 2  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller  \
# 0  Presencial    Entre 100 y 300
# 1  Presencial    Entre 100 y 300
# 2  Presencial    Entre 100 y 300
#
#                                                    Título  Nº Sesiones  \
# 0  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 1                  Desarrollo de habilidades lingüísticas            5
# 2           Fomentando la Creatividad a través del Teatro            4
#
#    Precio por taller Tipo de contenido  Valoración
# 0                100         Innovador           1
# 1                200      No innovador           4
# 2                400         Innovador           1

# %%
def objetivo_analisis(lectura):
    #objetivos = ['Ofrecer formación variada', 'Aumentar la participación de las familias', 'Sorprender con contenidos innovadores y formatos novedosos']
    path = '/Users/herminiapadialromera/ironhackb/Proyecto_final/notebooks/input_sist_recom_4.json'
    pd.set_option('display.max_colwidth', None)
    df_input_json = pd.read_json(path)
    
    print("Contenido de lectura['Objetivos']:")
    #print(lectura['Objetivos'])
    ob1= 'Ofrecer formación variada'
    ob2= 'Aumentar la participación de las familias'
    ob3= 'Sorprender con contenidos innovadores y formatos novedosos'

    if lectura['Objetivos'].str.contains(ob1).any():

        print("Condición de objetivos cumplida:")
        tematica_formato_etapa_df_test = filtro_tematica_etapa_formato(lectura, 5)
        filtro_precio_df = filtro_precio(tematica_formato_etapa_df_test)
        return filtro_precio_df
    
    elif lectura['Objetivos'].str.contains(ob2).any():
        print("Está el 2")
        filtro_valoracion_tematica_df = filtro_valoracion_tematica(lectura, 5)
        return filtro_valoracion_tematica_df
    
    elif lectura['Objetivos'].str.contains(ob3).any():
        print("Nada 2") 
        filtro_innovación_tematica_df = filtro_innovación_tematica(lectura, 5)
        return filtro_innovación_tematica_df 

    else:
        #resultado_check_educ_creci = check_educ_creci()
        df_sr4 = check_educ_creci()
        return filtro_edcrecim_tematica(df_sr4, 5)

# %%
type(lectura)
# Out:
# pandas.core.frame.DataFrame

# %%
resultado = objetivo_analisis(lectura)
resultado
# Out:
# Contenido de lectura['Objetivos']:
# Se agregó 'Educación & Crecimiento' a df_input_json['Temática']
#   Name_center Religious       Etapa                 Temática  \
# 0   Greenwich        No    Primaria     Familia & Tecnología
# 1   Greenwich        No    Primaria  Educación & Crecimiento
# 2   Greenwich        No  Secundaria           Arte & Cultura
#
#                                                             Objetivos  \
# 0  Solucionar problemas de comunicacion y actitud de niños y familias
# 1  Solucionar problemas de comunicacion y actitud de niños y familias
# 2  Solucionar problemas de comunicacion y actitud de niños y familias
#
#       Formato Precios por taller  \
# 0  Presencial    Entre 100 y 300
# 1  Presencial    Entre 100 y 300
# 2  Presencial    Entre 100 y 300
#
#                                                    Título  Nº Sesiones  \
# 0  ¿Qué harías si tu hijo fuera adicto a los videojuegos?            3
# 1                  Desarrollo de habilidades lingüísticas            5
# 2           Fomentando la Creatividad a través del Teatro            4
#
#    Precio por taller Tipo de contenido  Valoración
# 0                100         Innovador           1
# 1                200      No innovador           4
# 2                400         Innovador           1

# %%
type(resultado)
# Out:
# pandas.core.frame.DataFrame
