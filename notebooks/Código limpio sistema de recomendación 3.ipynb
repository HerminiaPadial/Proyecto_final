# %% [markdown]
# ## Imports

# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Lectura input

# %%
path = '/Users/herminiapadialromera/ironhackb/Proyecto_final/notebooks/input_sist_recom_3.json'
pd.set_option('display.max_colwidth', None)
df_input_json = pd.read_json(path)
df_input_json
# Out:
#    Provincia Name_center Religious                   Etapa
# 0  Barcelona   Greenwich        No  [Primaria, Secundaria]  \
#
#                                  Temática
# 0  [Familia & Tecnología, Arte & Cultura]  \
#
#                                                       Objetivos
# 0  [Sorprender con contenidos innovadores y formatos novedosos]  \
#
#                 Formato Precios por taller
# 0  [Presencial, Online]    Entre 100 y 300

# %%
columnas_explode = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
df_input_json_merge = df_input_json.explode(['Etapa']).explode(['Formato']).explode(['Objetivos']).explode(['Temática'])
df_input_json_merge
# Out:
#    Provincia Name_center Religious       Etapa              Temática
# 0  Barcelona   Greenwich        No    Primaria  Familia & Tecnología  \
# 0  Barcelona   Greenwich        No    Primaria        Arte & Cultura
# 0  Barcelona   Greenwich        No    Primaria  Familia & Tecnología
# 0  Barcelona   Greenwich        No    Primaria        Arte & Cultura
# 0  Barcelona   Greenwich        No  Secundaria  Familia & Tecnología
# 0  Barcelona   Greenwich        No  Secundaria        Arte & Cultura
# 0  Barcelona   Greenwich        No  Secundaria  Familia & Tecnología
# 0  Barcelona   Greenwich        No  Secundaria        Arte & Cultura
#
#                                                     Objetivos     Formato
# 0  Sorprender con contenidos innovadores y formatos novedosos  Presencial  \
# 0  Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 0  Sorprender con contenidos innovadores y formatos novedosos      Online
# 0  Sorprender con contenidos innovadores y formatos novedosos      Online
# 0  Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 0  Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 0  Sorprender con contenidos innovadores y formatos novedosos      Online
# 0  Sorprender con contenidos innovadores y formatos novedosos      Online
#
#   Precios por taller
# 0    Entre 100 y 300
# 0    Entre 100 y 300
# 0    Entre 100 y 300
# 0    Entre 100 y 300
# 0    Entre 100 y 300
# 0    Entre 100 y 300
# 0    Entre 100 y 300
# 0    Entre 100 y 300

# %% [markdown]
# ## Lectura del dataset de cursos

# %%
data_course_df = pd.read_csv('/Users/herminiapadialromera/ironhackb/Proyecto_final/data/Datos_ampliados.csv', sep=";", encoding='utf8')
data_course_df = pd.DataFrame(data_course_df)
data_course_df['Tipo de contenido'].fillna('No innovador', inplace= True)
columnas_explode_curso = ['Etapa', 'Formato', 'Temática', 'Objetivos'] 
data_course_df = data_course_df.explode(['Etapa']).explode(['Formato']).explode(['Temática'])
data_course_df
# Out:
#                                                       Título         Etapa
# 0              ¡Ponte al día con la Inteligencia Artificial!  Bachillerato  \
# 1              ¡Ponte al día con la Inteligencia Artificial!      Infantil
# 2              ¡Ponte al día con la Inteligencia Artificial!      Primaria
# 3              ¡Ponte al día con la Inteligencia Artificial!    Secundaria
# 4     ¿Qué harías si tu hijo fuera adicto a los videojuegos?  Bachillerato
# ..                                                       ...           ...
# 263  Violencia: Identificación y prevención con las familias      Infantil
# 264  Violencia: Identificación y prevención con las familias      Primaria
# 265  Violencia: Identificación y prevención con las familias      Primaria
# 266  Violencia: Identificación y prevención con las familias    Secundaria
# 267  Violencia: Identificación y prevención con las familias    Secundaria
#
#         Formato  Nº Sesiones                 Temática  Precio por taller
# 0        Online            5     Familia & Tecnología                130  \
# 1        Online            5     Familia & Tecnología                130
# 2        Online            5     Familia & Tecnología                130
# 3        Online            5     Familia & Tecnología                130
# 4    Presencial            3     Familia & Tecnología                100
# ..          ...          ...                      ...                ...
# 263      Online            3  Educación & Crecimiento                250
# 264  Presencial            3  Educación & Crecimiento                250
# 265      Online            3  Educación & Crecimiento                250
# 266  Presencial            3  Educación & Crecimiento                250
# 267      Online            3  Educación & Crecimiento                250
#
#      Provincia Tipo de contenido  Valoración
# 0       Madrid         Innovador           3
# 1       Madrid         Innovador           4
# 2       Madrid         Innovador           2
# 3       Madrid         Innovador           4
# 4    Barcelona         Innovador           2
# ..         ...               ...         ...
# 263   Valencia      No innovador           4
# 264   Valencia      No innovador           1
# 265   Valencia      No innovador           3
# 266   Valencia      No innovador           4
# 267   Valencia      No innovador           1
#
# [268 rows x 9 columns]

# %% [markdown]
# ## Merge de los dos dataframe

# %%
df_merge = pd.merge(df_input_json_merge, data_course_df, on=['Provincia', 'Etapa', 'Formato', 'Temática'])
df_merge = df_merge.iloc[:,1:]
df_merge
# Out:
#    Name_center Religious       Etapa              Temática
# 0    Greenwich        No    Primaria  Familia & Tecnología  \
# 1    Greenwich        No    Primaria  Familia & Tecnología
# 2    Greenwich        No    Primaria  Familia & Tecnología
# 3    Greenwich        No    Primaria  Familia & Tecnología
# 4    Greenwich        No    Primaria  Familia & Tecnología
# 5    Greenwich        No    Primaria  Familia & Tecnología
# 6    Greenwich        No  Secundaria  Familia & Tecnología
# 7    Greenwich        No  Secundaria  Familia & Tecnología
# 8    Greenwich        No  Secundaria  Familia & Tecnología
# 9    Greenwich        No  Secundaria  Familia & Tecnología
# 10   Greenwich        No  Secundaria        Arte & Cultura
# 11   Greenwich        No  Secundaria  Familia & Tecnología
# 12   Greenwich        No  Secundaria  Familia & Tecnología
# 13   Greenwich        No  Secundaria  Familia & Tecnología
# 14   Greenwich        No  Secundaria        Arte & Cultura
#
#                                                      Objetivos     Formato
# 0   Sorprender con contenidos innovadores y formatos novedosos  Presencial  \
# 1   Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 2   Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 3   Sorprender con contenidos innovadores y formatos novedosos      Online
# 4   Sorprender con contenidos innovadores y formatos novedosos      Online
# 5   Sorprender con contenidos innovadores y formatos novedosos      Online
# 6   Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 7   Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 8   Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 9   Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 10  Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 11  Sorprender con contenidos innovadores y formatos novedosos      Online
# 12  Sorprender con contenidos innovadores y formatos novedosos      Online
# 13  Sorprender con contenidos innovadores y formatos novedosos      Online
# 14  Sorprender con contenidos innovadores y formatos novedosos      Online
#
#    Precios por taller                                                  Título
# 0     Entre 100 y 300  ¿Qué harías si tu hijo fuera adicto a los videojuegos?  \
# 1     Entre 100 y 300                             Aprende a Diseñar con Canva
# 2     Entre 100 y 300        Creación de Animaciones Interactivas con Scratch
# 3     Entre 100 y 300  ¿Qué harías si tu hijo fuera adicto a los videojuegos?
# 4     Entre 100 y 300                     Dibujo y Pintura Digital para Niños
# 5     Entre 100 y 300         Explorando el Diseño de Videojuegos con Scratch
# 6     Entre 100 y 300  ¿Qué harías si tu hijo fuera adicto a los videojuegos?
# 7     Entre 100 y 300                       Aprendiendo a Programar en Python
# 8     Entre 100 y 300                 Descubriendo el universo de la biología
# 9     Entre 100 y 300                  Descubriendo el universo de la química
# 10    Entre 100 y 300           Fomentando la Creatividad a través del Teatro
# 11    Entre 100 y 300  ¿Qué harías si tu hijo fuera adicto a los videojuegos?
# 12    Entre 100 y 300               Descubriendo el universo de la astronomía
# 13    Entre 100 y 300       Introducción a la Programación Web con HTML y CSS
# 14    Entre 100 y 300            Descubre el Arte de la Improvisación Teatral
#
#     Nº Sesiones  Precio por taller Tipo de contenido  Valoración
# 0             3                100         Innovador           1
# 1             5                 80      No innovador           4
# 2             3                100         Innovador           3
# 3             3                100         Innovador           2
# 4             5                 80      No innovador           5
# 5             3                100         Innovador           1
# 6             3                100         Innovador           3
# 7             3                100         Innovador           5
# 8             5                180      No innovador           5
# 9             5                180      No innovador           4
# 10            4                400         Innovador           1
# 11            3                100         Innovador           5
# 12            5                180      No innovador           2
# 13            3                100         Innovador           2
# 14            4                150         Innovador           3

# %% [markdown]
# ## FILTROS

# %% [markdown]
#    ## Filtro temática e innovación

# %%
def filtro_innovación_tematica (df, sesiones):
    tematica_unique_list = df_merge['Temática'].unique()

    filtro_inno_tematica_df = pd.DataFrame()
    for tematica in tematica_unique_list:
        df_inno_tematica = df_merge[(df_merge['Nº Sesiones'] <= int(f"{sesiones}")) & (df_merge['Tipo de contenido'] == 'Innovador') & (df_merge['Temática'] == tematica)]
        filtro_inno_tematica_df = pd.concat([filtro_inno_tematica_df, df_inno_tematica.head(2)])
        print("filtro_inno_tematica_df ---> ", tematica)

    recomendaciones_innovacion_tema_df = filtro_inno_tematica_df.drop_duplicates().reset_index(drop=True)


    return recomendaciones_innovacion_tema_df

# %%
recomendacion_3 = filtro_innovación_tematica (df_merge, 5)
recomendacion_3
# Out:
# filtro_inno_tematica_df --->  Familia & Tecnología
# filtro_inno_tematica_df --->  Arte & Cultura
#   Name_center Religious       Etapa              Temática
# 0   Greenwich        No    Primaria  Familia & Tecnología  \
# 1   Greenwich        No    Primaria  Familia & Tecnología
# 2   Greenwich        No  Secundaria        Arte & Cultura
# 3   Greenwich        No  Secundaria        Arte & Cultura
#
#                                                     Objetivos     Formato
# 0  Sorprender con contenidos innovadores y formatos novedosos  Presencial  \
# 1  Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 2  Sorprender con contenidos innovadores y formatos novedosos  Presencial
# 3  Sorprender con contenidos innovadores y formatos novedosos      Online
#
#   Precios por taller                                                  Título
# 0    Entre 100 y 300  ¿Qué harías si tu hijo fuera adicto a los videojuegos?  \
# 1    Entre 100 y 300        Creación de Animaciones Interactivas con Scratch
# 2    Entre 100 y 300           Fomentando la Creatividad a través del Teatro
# 3    Entre 100 y 300            Descubre el Arte de la Improvisación Teatral
#
#    Nº Sesiones  Precio por taller Tipo de contenido  Valoración
# 0            3                100         Innovador           1
# 1            3                100         Innovador           3
# 2            4                400         Innovador           1
# 3            4                150         Innovador           3
